# %%
import pandas as pd

dtype_map = {
    'product_id': 'string',
    'product_name': 'string',
    'category_id': 'string',
    'brand': 'string',
    'price': 'string',
    'cost': 'string',
    'stock_quantity': 'string',
    'weight_kg': 'string',
    'dimensions': 'string',
    'description': 'string',
    'is_active': 'string',
    'created_at': 'string'
}

df_products = pd.read_csv('../../data/raw/products.csv', dtype=dtype_map)
df_products.head()
# Out:
#    Unnamed: 0 product_id                               product_name  \
# 0           0          1     Centralized attitude-oriented synergy
# 1           1          2             Reactive asynchronous analyzer
# 2           2          3               Polarized static flexibility
# 3           3          4  Persevering homogeneous Graphic Interface
# 4           4          5              Compatible non-volatile array
#
#   category_id          brand   price    cost stock_quantity weight_kg  \
# 0         164      undefined  120.22   49.48            754      <NA>
# 1           9         Adidas   19.75   10.92             27     28.11
# 2          57    Dr. Martens  454.72  334.06            777     40.31
# 3          56  Tiffany & Co.  957.64   331.7           <NA>      <NA>
# 4         118           IKEA  540.87  311.55           <NA>     31.47
#
#     dimensions                                        description is_active  \
# 0  194x144x13   Hotel quickly amount care meet. Likely conside...      True
# 1   188x171x91  Wish white also. Natural career woman across c...      True
# 2   183x113x45  Senior go talk down story forget. Career make ...      True
# 3    93x159x35  Exist little add economy discussion across. Pe...      True
# 4    97x152x26  Stuff evening north city he sit style poor. Pe...      True
#
#                     created_at
# 0   2024-05-12T00:44:32.354038
# 1   2024-06-13T17:16:40.512421
# 2   2025-01-02T18:13:21.175439
# 3   2024-12-15T11:32:56.088835
# 4   2023-12-05T09:19:11.197502

# %% [markdown]
# Vamos a descartar las columnas que son innecesarias para nuestro análisis.

# %%
df_products.drop(columns=['Unnamed: 0'], inplace=True)

# %%
df_products_clean = df_products.set_index('product_id')

# DATES
df_products_clean['created_at'] = df_products_clean['created_at'].str.strip()
df_products_clean['created_at'] = pd.to_datetime(df_products_clean['created_at'], errors='coerce')

# BOOLEANS
df_products_clean['is_active'] = df_products_clean['is_active'].str.strip().str.lower()
df_products_clean['is_active'] = (
    df_products_clean['is_active']
    .map({"true": True, "false": False, "1": True, "0": False})
    .astype("boolean")
)

# INTEGERS
for col in ['category_id']:
    df_products_clean[col] = df_products_clean[col].str.strip()
    df_products_clean[col] = pd.to_numeric(df_products_clean[col], errors='coerce').astype('Int64')

# FLOATS
for col in ['price', 'cost', 'stock_quantity', 'weight_kg']:
    df_products_clean[col] = df_products_clean[col].str.strip()
    df_products_clean[col] = pd.to_numeric(df_products_clean[col], errors='coerce')

# STRINGS
for col in ['product_name', 'description', 'dimensions']:
    df_products_clean[col] = df_products_clean[col].str.strip()

# CATEGORICAL
df_products_clean['brand'] = df_products_clean['brand'].str.strip().str.title().astype('category')

df_products_clean.head()
# Out:
#                                          product_name  category_id  \
# product_id
# 1               Centralized attitude-oriented synergy          164
# 2                      Reactive asynchronous analyzer            9
# 3                        Polarized static flexibility           57
# 4           Persevering homogeneous Graphic Interface           56
# 5                       Compatible non-volatile array          118
#
#                     brand   price    cost  stock_quantity  weight_kg  \
# product_id
# 1               Undefined  120.22   49.48             754       <NA>
# 2                  Adidas   19.75   10.92              27      28.11
# 3             Dr. Martens  454.72  334.06             777      40.31
# 4           Tiffany & Co.  957.64   331.7            <NA>       <NA>
# 5                    Ikea  540.87  311.55            <NA>      31.47
#
#             dimensions                                        description  \
# product_id
# 1           194x144x13  Hotel quickly amount care meet. Likely conside...
# 2           188x171x91  Wish white also. Natural career woman across c...
# 3           183x113x45  Senior go talk down story forget. Career make ...
# 4            93x159x35  Exist little add economy discussion across. Pe...
# 5            97x152x26  Stuff evening north city he sit style poor. Pe...
#
#             is_active                 created_at
# product_id
# 1                True 2024-05-12 00:44:32.354038
# 2                True 2024-06-13 17:16:40.512421
# 3                True 2025-01-02 18:13:21.175439
# 4                True 2024-12-15 11:32:56.088835
# 5                True 2023-12-05 09:19:11.197502

# %% [markdown]
# Exportamos el dataset limpio para reutilizarlo.

# %%
df_products_clean.to_pickle('../../data/clean/products.pkl')
